# %%
import mxnet as mx
from mxnet import gluon
from mxnet import ndarray as nd
from mxnet import autograd
from mxnet.gluon import nn

import os
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

ctx = mx.gpu()

# %%
root_dir = "/data/ai/data/kaggle_dog-breed-identification/"
data_dir = os.path.join(root_dir, "data")
features_dir = os.path.join(root_dir, "features")

# %%
softmax_cross_entropy = gluon.loss.SoftmaxCrossEntropyLoss()

def accuracy(output, labels):
    return nd.mean(nd.argmax(output, axis=1) == labels).asscalar()

def evaluate(net, data_iter):
    loss, acc, n = 0., 0., 0.
    steps = len(data_iter)
    for data, label in data_iter:
        data, label = data.as_in_context(ctx), label.as_in_context(ctx)
        output = net(data)
        acc += accuracy(output, label)
        loss += nd.mean(softmax_cross_entropy(output, label)).asscalar()
    return loss/steps, acc/steps

# %%
def load_data(model_name, batch_size=128, train_size=0.8):
    features = nd.load(os.path.join(features_dir,'features_train_%s.nd' % model_name))[0]
    labels = nd.load(os.path.join(data_dir,'labels.nd'))[0]
    print("features", features.shape, "labels", labels.shape)

    n_train = int(features.shape[0]*train_size)

    X_train = features[:n_train]
    y_train = labels[:n_train]

    X_val = features[n_train:]
    y_val = labels[n_train:]

    dataset_train = gluon.data.ArrayDataset(X_train, y_train)
    dataset_val = gluon.data.ArrayDataset(X_val, y_val)

    data_iter_train = gluon.data.DataLoader(dataset_train, batch_size)
    data_iter_val = gluon.data.DataLoader(dataset_val, batch_size)
    
    return data_iter_train, data_iter_val

# %%
# D1:512 No activation, drop 0.9 : 0.4647
# D1:512 No activation, drop 0.8 : 0.4430
# D1:512 No activation, drop 0.5 : 0.4941 
# D1:512 No activation, drop 0.3 : 0.5275
# D1:512 activation, drop 0.8 : 0.4667
# D1:512 activation, drop 0.5 : 0.4476
# D1:256 activation, drop 0.5 : 0.4540
# D1:512 No activation, Batch Norm, activation, drop 0.8 : 0.4649
# D1:512 No activation, Batch Norm,  drop 0.8 : 0.4594
# D1:1024 No activation, drop 0.8 : 0.5080
# D1:1024 activation, drop 0.8: 0.4444
# D1:1024 activation, drop 0.9: 0.4794
# No D1, No drop: 0.4929 
# No D1, Drop 0.8: 0.5119
# No D1, Batch norm, activation, drop 0.8: 0.5338

def build_model():
    net = nn.Sequential()
    with net.name_scope():
        net.add(nn.Dense(512, activation='relu'))
        #net.add(nn.BatchNorm(axis=1))
        #net.add(nn.Dropout(0.5))
        net.add(nn.Dropout(0.85))
        net.add(nn.Dense(120))

    net.initialize(ctx=ctx)
    return net

# %%
def train_model(model_name):
    epochs = 50
    batch_size = 128
    
    data_iter_train, data_iter_val = load_data(model_name, batch_size)
    net = build_model()
    
    trainer = gluon.Trainer(net.collect_params(), 'adam', {'learning_rate': 1e-4, 'wd': 1e-5})
    
    for epoch in range(epochs):
        train_loss = 0.
        train_acc = 0.
        steps = len(data_iter_train)
        for data, label in data_iter_train:
            data, label = data.as_in_context(ctx), label.as_in_context(ctx)

            with autograd.record():
                output = net(data)
                loss = softmax_cross_entropy(output, label)

            loss.backward()
            trainer.step(batch_size)

            train_loss += nd.mean(loss).asscalar()
            train_acc += accuracy(output, label)

        val_loss, val_acc = evaluate(net, data_iter_val)
    
    print("Epoch %d. loss: %.4f, acc: %.2f%%, val_loss %.4f, val_acc %.2f%% Model: %s" % (
        epoch+1, train_loss/steps, train_acc/steps*100, val_loss, val_acc*100, model_name))
    
    return val_loss

# %%
from mxnet.gluon.model_zoo.model_store import _model_sha1

losses = []

for model_name in sorted(_model_sha1.keys()):
    if model_name in {"vgg11", "vgg11_bn", "vgg13", "vgg13_bn", 'vgg16', 'vgg16_bn', 'vgg19', 'vgg19_bn', 
                     "densenet161", "densenet201" }:
        pass
    else:
        print("training", model_name)
        val_loss = train_model(model_name)
        losses.append((model_name, val_loss))
# Out:
# training alexnet
# features (10222, 9216) labels (10222,)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-33-b28a65fba67c> in <module>()
#       9     else:
#      10         print("training", model_name)
# ---> 11         val_loss = train_model(model_name)
#      12         losses.append((model_name, val_loss))
#
# <ipython-input-32-3f9afa1c8116> in train_model(model_name)
#      19                 loss = softmax_cross_entropy(output, label)
#      20
# ---> 21             loss.backward()
#      22             trainer.step(batch_size)
#      23
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/mxnet/ndarray/ndarray.py in backward(self, out_grad, retain_graph, train_mode)
#    1751
#    1752         check_call(_LIB.MXAutogradBackwardEx(
# -> 1753             1, c_array(NDArrayHandle, [self.handle]),
#    1754             c_array(NDArrayHandle, ograd_handles),
#    1755             0,
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/mxnet/base.py in c_array(ctype, values)
#     214     2.0
#     215     """
# --> 216     return (ctype * len(values))(*values)
#     217
#     218 def ctypes2buffer(cptr, length):
#
# KeyboardInterrupt:

# %%
df = pd.DataFrame(losses, columns=['model', 'val_loss'])
df = df.sort_values('val_loss')
df.head(20)
# Out:
#             model  val_loss
# 3     inceptionv3  0.284268
# 5    resnet152_v1  0.402438
# 4    resnet101_v1  0.412058
# 10    resnet50_v1  0.512563
# 2     densenet169  0.516145
# 11    resnet50_v2  0.597712
# 8     resnet34_v1  0.620733
# 1     densenet121  0.622118
# 9     resnet34_v2  0.676297
# 6     resnet18_v1  0.871806
# 7     resnet18_v2  1.023909
# 13  squeezenet1.1  1.945257
# 12  squeezenet1.0  1.978309
# 0         alexnet  3.152370

# %%
df.to_csv('models.csv', index=None)
pd.read_csv('models.csv')
for i, (model_name, val_loss) in df.iterrows():
    print('%s | %s' % (model_name, val_loss))
df.head(10)
# Out:
# inceptionv3 | 0.28426791448146105
# resnet152_v1 | 0.40243762359023094
# resnet101_v1 | 0.4120584465563297
# resnet50_v1 | 0.5125632397830486
# densenet169 | 0.5161446258425713
# resnet50_v2 | 0.5977117847651243
# resnet34_v1 | 0.6207333207130432
# densenet121 | 0.6221175324171782
# resnet34_v2 | 0.6762965656816959
# resnet18_v1 | 0.8718055002391338
# resnet18_v2 | 1.023909479379654
# squeezenet1.1 | 1.9452572986483574
# squeezenet1.0 | 1.9783090502023697
# alexnet | 3.152370259165764
#            model  val_loss
# 3    inceptionv3  0.284268
# 5   resnet152_v1  0.402438
# 4   resnet101_v1  0.412058
# 10   resnet50_v1  0.512563
# 2    densenet169  0.516145
# 11   resnet50_v2  0.597712
# 8    resnet34_v1  0.620733
# 1    densenet121  0.622118
# 9    resnet34_v2  0.676297
# 6    resnet18_v1  0.871806

# %%
def load_models_data(model_names, batch_size=128, train_size=0.8):
    features = [nd.load(os.path.join(features_dir, 'features_train_%s.nd' % model_name))[0] for model_name in model_names]
    features = nd.concat(*features, dim=1)
    labels = nd.load(os.path.join(data_dir, 'labels.nd'))[0]
    
    #X_train, X_val, y_train, y_val = train_test_split(features, labels, test_size= 1 - train_size)
    n_train = int(features.shape[0]*train_size)
    
    X_train = features[:n_train]
    y_train = labels[:n_train]

    X_val = features[n_train:]
    y_val = labels[n_train:]
    
    dataset_train = gluon.data.ArrayDataset(X_train, y_train)
    dataset_val = gluon.data.ArrayDataset(X_val, y_val)

    data_iter_train = gluon.data.DataLoader(dataset_train, batch_size, shuffle=True)
    data_iter_val = gluon.data.DataLoader(dataset_val, batch_size)
    
    return data_iter_train, data_iter_val

# %%
net = build_model()

epochs = 500
batch_size = 128

#model_names = ['inceptionv3', 'resnet152_v1']
model_names = ['inceptionv3', 'resnet152_v1', 'resnet101_v1']#, 'resnet50_v1'] #, 'densenet169'] #, 'resnet101_v1']#, 'resnet152_v1'] #resnet34_v2']#, 'resnet50_v2']
data_iter_train, data_iter_val = load_models_data(model_names, batch_size=batch_size)


lr_sch = mx.lr_scheduler.FactorScheduler(step=400, factor=0.9)
trainer = gluon.Trainer(net.collect_params(), 'adam', 
                        {'learning_rate': 1e-4, 'wd': 1e-5, 'lr_scheduler': lr_sch})

# %%
for epoch in range(epochs):
    train_loss = 0.
    train_acc = 0.
    steps = len(data_iter_train)
    for data, label in data_iter_train:
        data, label = data.as_in_context(ctx), label.as_in_context(ctx)

        with autograd.record():
            output = net(data)
            loss = softmax_cross_entropy(output, label)

        loss.backward()
        trainer.step(batch_size)

        train_loss += nd.mean(loss).asscalar()
        train_acc += accuracy(output, label)

    val_loss, val_acc = evaluate(net, data_iter_val)

    print("Epoch %d. loss: %.4f, acc: %.2f%%, val_loss %.4f, val_acc %.2f%%" % (
        epoch+1, train_loss/steps, train_acc/steps*100, val_loss, val_acc*100))
# Out:
# Epoch 1. loss: 5.2794, acc: 1.99%, val_loss 4.4801, val_acc 17.06%
# Epoch 2. loss: 4.4706, acc: 5.23%, val_loss 3.9625, val_acc 39.76%
# Epoch 3. loss: 4.0767, acc: 10.44%, val_loss 3.2703, val_acc 59.13%
# Epoch 4. loss: 3.6066, acc: 18.44%, val_loss 2.5628, val_acc 69.54%
# Epoch 5. loss: 3.1294, acc: 26.96%, val_loss 1.9564, val_acc 76.43%
# Epoch 6. loss: 2.7592, acc: 33.36%, val_loss 1.5276, val_acc 80.54%
# Epoch 7. loss: 2.4338, acc: 39.86%, val_loss 1.2044, val_acc 82.93%
# Epoch 8. loss: 2.2081, acc: 44.57%, val_loss 1.0068, val_acc 85.23%
# Epoch 9. loss: 1.9641, acc: 49.65%, val_loss 0.8403, val_acc 85.62%
# Epoch 10. loss: 1.8241, acc: 52.88%, val_loss 0.7373, val_acc 86.70%
# Epoch 11. loss: 1.6895, acc: 55.90%, val_loss 0.6559, val_acc 87.24%
# Epoch 12. loss: 1.5929, acc: 57.77%, val_loss 0.5862, val_acc 88.12%
# Epoch 13. loss: 1.4800, acc: 60.31%, val_loss 0.5438, val_acc 88.17%
# Epoch 14. loss: 1.3733, acc: 63.00%, val_loss 0.5020, val_acc 88.51%
# Epoch 15. loss: 1.3105, acc: 64.45%, val_loss 0.4680, val_acc 88.51%
# Epoch 16. loss: 1.2644, acc: 65.27%, val_loss 0.4503, val_acc 89.10%
# Epoch 17. loss: 1.2024, acc: 67.02%, val_loss 0.4335, val_acc 89.44%
# Epoch 18. loss: 1.1832, acc: 67.77%, val_loss 0.4170, val_acc 89.15%
# Epoch 19. loss: 1.1110, acc: 69.49%, val_loss 0.4014, val_acc 88.80%
# Epoch 20. loss: 1.0770, acc: 70.08%, val_loss 0.3883, val_acc 89.29%
# Epoch 21. loss: 1.0396, acc: 71.14%, val_loss 0.3795, val_acc 88.95%
# Epoch 22. loss: 1.0217, acc: 71.57%, val_loss 0.3745, val_acc 89.14%
# Epoch 23. loss: 1.0033, acc: 71.92%, val_loss 0.3626, val_acc 89.04%
# Epoch 24. loss: 0.9473, acc: 73.03%, val_loss 0.3578, val_acc 89.68%
# Epoch 25. loss: 0.9309, acc: 73.90%, val_loss 0.3492, val_acc 89.44%
# Epoch 26. loss: 0.8990, acc: 75.15%, val_loss 0.3460, val_acc 89.73%
# Epoch 27. loss: 0.9003, acc: 74.88%, val_loss 0.3435, val_acc 89.54%
# Epoch 28. loss: 0.8858, acc: 74.56%, val_loss 0.3382, val_acc 90.32%
# Epoch 29. loss: 0.8317, acc: 75.84%, val_loss 0.3313, val_acc 90.12%
# Epoch 30. loss: 0.8090, acc: 76.77%, val_loss 0.3302, val_acc 89.98%
# Epoch 31. loss: 0.8054, acc: 77.32%, val_loss 0.3265, val_acc 90.27%
# Epoch 32. loss: 0.7906, acc: 77.63%, val_loss 0.3213, val_acc 90.02%
# Epoch 33. loss: 0.7857, acc: 77.42%, val_loss 0.3237, val_acc 90.07%
# Epoch 34. loss: 0.7437, acc: 78.72%, val_loss 0.3172, val_acc 89.83%
# Epoch 35. loss: 0.7625, acc: 78.57%, val_loss 0.3173, val_acc 90.17%
# Epoch 36. loss: 0.7270, acc: 79.28%, val_loss 0.3162, val_acc 90.02%
# Epoch 37. loss: 0.7023, acc: 79.56%, val_loss 0.3141, val_acc 90.22%
# Epoch 38. loss: 0.7281, acc: 78.90%, val_loss 0.3095, val_acc 90.07%
# Epoch 39. loss: 0.6946, acc: 80.08%, val_loss 0.3081, val_acc 89.97%
# Epoch 40. loss: 0.6746, acc: 80.25%, val_loss 0.3031, val_acc 90.71%
# Epoch 41. loss: 0.6880, acc: 80.10%, val_loss 0.3042, val_acc 90.32%
# Epoch 42. loss: 0.6663, acc: 81.23%, val_loss 0.3045, val_acc 90.27%
# Epoch 43. loss: 0.6561, acc: 80.85%, val_loss 0.3010, val_acc 90.32%
# Epoch 44. loss: 0.6626, acc: 80.87%, val_loss 0.2974, val_acc 90.46%
# Epoch 45. loss: 0.6433, acc: 81.41%, val_loss 0.2981, val_acc 90.61%
# Epoch 46. loss: 0.6321, acc: 81.31%, val_loss 0.2960, val_acc 90.61%
# Epoch 47. loss: 0.6238, acc: 81.63%, val_loss 0.2961, val_acc 90.56%
# Epoch 48. loss: 0.6181, acc: 82.21%, val_loss 0.2947, val_acc 90.56%
# Epoch 49. loss: 0.6144, acc: 81.98%, val_loss 0.2905, val_acc 90.61%
# Epoch 50. loss: 0.6045, acc: 82.21%, val_loss 0.2961, val_acc 90.61%
# Epoch 51. loss: 0.5869, acc: 83.24%, val_loss 0.2913, val_acc 90.46%
# Epoch 52. loss: 0.5877, acc: 82.64%, val_loss 0.2894, val_acc 90.95%
# Epoch 53. loss: 0.5786, acc: 82.74%, val_loss 0.2921, val_acc 90.37%
# Epoch 54. loss: 0.5778, acc: 82.70%, val_loss 0.2910, val_acc 90.66%
# Epoch 55. loss: 0.5728, acc: 83.37%, val_loss 0.2891, val_acc 90.66%
# Epoch 56. loss: 0.5605, acc: 83.23%, val_loss 0.2851, val_acc 90.66%
# Epoch 57. loss: 0.5611, acc: 83.59%, val_loss 0.2886, val_acc 91.05%
# Epoch 58. loss: 0.5640, acc: 83.62%, val_loss 0.2864, val_acc 90.76%
# Epoch 59. loss: 0.5654, acc: 83.52%, val_loss 0.2858, val_acc 90.61%
# Epoch 60. loss: 0.5451, acc: 83.88%, val_loss 0.2867, val_acc 90.71%
# Epoch 61. loss: 0.5241, acc: 84.70%, val_loss 0.2840, val_acc 90.85%
# Epoch 62. loss: 0.5320, acc: 84.10%, val_loss 0.2844, val_acc 91.05%
# Epoch 63. loss: 0.5117, acc: 84.78%, val_loss 0.2831, val_acc 90.61%
# Epoch 64. loss: 0.5242, acc: 84.64%, val_loss 0.2822, val_acc 90.90%
# Epoch 65. loss: 0.5206, acc: 84.67%, val_loss 0.2830, val_acc 90.71%
# Epoch 66. loss: 0.5257, acc: 84.68%, val_loss 0.2814, val_acc 90.71%
# Epoch 67. loss: 0.5270, acc: 84.37%, val_loss 0.2797, val_acc 90.90%
# Epoch 68. loss: 0.5235, acc: 84.32%, val_loss 0.2786, val_acc 91.05%
# Epoch 69. loss: 0.4999, acc: 84.99%, val_loss 0.2795, val_acc 90.95%
# Epoch 70. loss: 0.4946, acc: 85.19%, val_loss 0.2793, val_acc 90.90%
# Epoch 71. loss: 0.4886, acc: 85.18%, val_loss 0.2792, val_acc 90.71%
# Epoch 72. loss: 0.4881, acc: 85.82%, val_loss 0.2779, val_acc 90.90%
# Epoch 73. loss: 0.4996, acc: 85.42%, val_loss 0.2793, val_acc 90.90%
# Epoch 74. loss: 0.4762, acc: 85.75%, val_loss 0.2790, val_acc 91.00%
# Epoch 75. loss: 0.4752, acc: 85.65%, val_loss 0.2785, val_acc 90.76%
# Epoch 76. loss: 0.4905, acc: 85.15%, val_loss 0.2757, val_acc 90.81%
# Epoch 77. loss: 0.4716, acc: 86.23%, val_loss 0.2759, val_acc 90.95%
# Epoch 78. loss: 0.4732, acc: 85.85%, val_loss 0.2777, val_acc 91.10%
# Epoch 79. loss: 0.4780, acc: 85.74%, val_loss 0.2770, val_acc 90.95%
# Epoch 80. loss: 0.4713, acc: 86.19%, val_loss 0.2766, val_acc 91.05%
# Epoch 81. loss: 0.4609, acc: 86.19%, val_loss 0.2758, val_acc 90.85%
# Epoch 82. loss: 0.4643, acc: 86.29%, val_loss 0.2758, val_acc 91.15%
# Epoch 83. loss: 0.4578, acc: 86.18%, val_loss 0.2770, val_acc 90.86%
# Epoch 84. loss: 0.4624, acc: 86.69%, val_loss 0.2768, val_acc 91.10%
# Epoch 85. loss: 0.4571, acc: 86.31%, val_loss 0.2743, val_acc 90.86%
# Epoch 86. loss: 0.4574, acc: 86.28%, val_loss 0.2732, val_acc 90.85%
# Epoch 87. loss: 0.4608, acc: 86.35%, val_loss 0.2732, val_acc 90.85%
# Epoch 88. loss: 0.4454, acc: 87.02%, val_loss 0.2737, val_acc 90.90%
# Epoch 89. loss: 0.4385, acc: 86.96%, val_loss 0.2721, val_acc 90.95%
# Epoch 90. loss: 0.4398, acc: 86.48%, val_loss 0.2728, val_acc 90.95%
# Epoch 91. loss: 0.4370, acc: 87.06%, val_loss 0.2738, val_acc 91.00%
# Epoch 92. loss: 0.4381, acc: 87.04%, val_loss 0.2728, val_acc 90.76%
# Epoch 93. loss: 0.4307, acc: 87.00%, val_loss 0.2742, val_acc 90.95%
# Epoch 94. loss: 0.4201, acc: 87.35%, val_loss 0.2735, val_acc 91.00%
# Epoch 95. loss: 0.4380, acc: 87.03%, val_loss 0.2727, val_acc 91.00%
# Epoch 96. loss: 0.4212, acc: 87.42%, val_loss 0.2726, val_acc 91.10%
# Epoch 97. loss: 0.4259, acc: 87.33%, val_loss 0.2728, val_acc 91.00%
# Epoch 98. loss: 0.4231, acc: 87.67%, val_loss 0.2734, val_acc 90.86%
# Epoch 99. loss: 0.4218, acc: 87.43%, val_loss 0.2722, val_acc 91.15%
# Epoch 100. loss: 0.4249, acc: 88.02%, val_loss 0.2728, val_acc 90.95%
# Epoch 101. loss: 0.4192, acc: 87.48%, val_loss 0.2722, val_acc 90.95%
# Epoch 102. loss: 0.4198, acc: 87.32%, val_loss 0.2715, val_acc 91.10%
# Epoch 103. loss: 0.4202, acc: 87.11%, val_loss 0.2719, val_acc 91.00%
# Epoch 104. loss: 0.4103, acc: 87.89%, val_loss 0.2731, val_acc 90.81%
# Epoch 105. loss: 0.4209, acc: 87.33%, val_loss 0.2732, val_acc 90.95%
# Epoch 106. loss: 0.3964, acc: 87.88%, val_loss 0.2745, val_acc 90.86%
# Epoch 107. loss: 0.4151, acc: 87.56%, val_loss 0.2726, val_acc 90.85%
# Epoch 108. loss: 0.3964, acc: 88.39%, val_loss 0.2713, val_acc 91.00%
# Epoch 109. loss: 0.4047, acc: 87.59%, val_loss 0.2715, val_acc 91.10%
# Epoch 110. loss: 0.4036, acc: 88.35%, val_loss 0.2726, val_acc 91.00%
# Epoch 111. loss: 0.4062, acc: 88.14%, val_loss 0.2718, val_acc 91.10%
# Epoch 112. loss: 0.4004, acc: 88.04%, val_loss 0.2717, val_acc 91.05%
# Epoch 113. loss: 0.4002, acc: 87.89%, val_loss 0.2715, val_acc 90.95%
# Epoch 114. loss: 0.4030, acc: 87.81%, val_loss 0.2713, val_acc 91.10%
# Epoch 115. loss: 0.4057, acc: 87.62%, val_loss 0.2701, val_acc 90.95%
# Epoch 116. loss: 0.3918, acc: 88.05%, val_loss 0.2707, val_acc 90.90%
# Epoch 117. loss: 0.3982, acc: 88.36%, val_loss 0.2705, val_acc 91.00%
# Epoch 118. loss: 0.3984, acc: 88.47%, val_loss 0.2708, val_acc 91.00%
# Epoch 119. loss: 0.3975, acc: 88.27%, val_loss 0.2698, val_acc 91.10%
# Epoch 120. loss: 0.3847, acc: 88.54%, val_loss 0.2702, val_acc 90.86%
# Epoch 121. loss: 0.3943, acc: 87.78%, val_loss 0.2703, val_acc 91.10%
# Epoch 122. loss: 0.3920, acc: 88.38%, val_loss 0.2702, val_acc 91.10%
# Epoch 123. loss: 0.3857, acc: 88.60%, val_loss 0.2712, val_acc 91.00%
# Epoch 124. loss: 0.3856, acc: 88.57%, val_loss 0.2709, val_acc 91.05%
# Epoch 125. loss: 0.3883, acc: 88.42%, val_loss 0.2695, val_acc 91.15%
# Epoch 126. loss: 0.3798, acc: 88.68%, val_loss 0.2688, val_acc 91.00%
# Epoch 127. loss: 0.3839, acc: 88.89%, val_loss 0.2701, val_acc 91.00%
# Epoch 128. loss: 0.3777, acc: 88.65%, val_loss 0.2699, val_acc 91.20%
# Epoch 129. loss: 0.3732, acc: 88.75%, val_loss 0.2711, val_acc 90.85%
# Epoch 130. loss: 0.3779, acc: 88.12%, val_loss 0.2704, val_acc 90.90%
# Epoch 131. loss: 0.3809, acc: 88.59%, val_loss 0.2693, val_acc 91.05%
# Epoch 132. loss: 0.3856, acc: 88.30%, val_loss 0.2689, val_acc 91.15%
# Epoch 133. loss: 0.3804, acc: 88.67%, val_loss 0.2688, val_acc 90.95%
# Epoch 134. loss: 0.3808, acc: 88.65%, val_loss 0.2694, val_acc 91.05%
# Epoch 135. loss: 0.3714, acc: 88.94%, val_loss 0.2702, val_acc 91.00%
# Epoch 136. loss: 0.3693, acc: 88.99%, val_loss 0.2685, val_acc 91.10%
# Epoch 137. loss: 0.3716, acc: 88.79%, val_loss 0.2687, val_acc 91.15%
# Epoch 138. loss: 0.3743, acc: 89.18%, val_loss 0.2683, val_acc 91.05%
# Epoch 139. loss: 0.3719, acc: 88.89%, val_loss 0.2687, val_acc 91.05%
# Epoch 140. loss: 0.3673, acc: 88.81%, val_loss 0.2689, val_acc 91.05%
# Epoch 141. loss: 0.3692, acc: 88.93%, val_loss 0.2698, val_acc 91.05%
# Epoch 142. loss: 0.3588, acc: 89.41%, val_loss 0.2692, val_acc 91.20%
# Epoch 143. loss: 0.3581, acc: 89.14%, val_loss 0.2686, val_acc 91.29%
# Epoch 144. loss: 0.3523, acc: 89.50%, val_loss 0.2682, val_acc 91.34%
# Epoch 145. loss: 0.3689, acc: 88.87%, val_loss 0.2691, val_acc 91.15%
# Epoch 146. loss: 0.3630, acc: 89.18%, val_loss 0.2684, val_acc 91.25%
# Epoch 147. loss: 0.3695, acc: 88.71%, val_loss 0.2684, val_acc 91.10%
# Epoch 148. loss: 0.3715, acc: 88.90%, val_loss 0.2685, val_acc 91.25%
# Epoch 149. loss: 0.3773, acc: 88.63%, val_loss 0.2681, val_acc 91.10%
# Epoch 150. loss: 0.3632, acc: 89.06%, val_loss 0.2685, val_acc 91.20%
# Epoch 151. loss: 0.3613, acc: 89.40%, val_loss 0.2684, val_acc 91.20%
# Epoch 152. loss: 0.3496, acc: 89.39%, val_loss 0.2684, val_acc 91.15%
# Epoch 153. loss: 0.3646, acc: 89.26%, val_loss 0.2687, val_acc 91.20%
# Epoch 154. loss: 0.3542, acc: 89.44%, val_loss 0.2691, val_acc 91.15%
# Epoch 155. loss: 0.3622, acc: 89.09%, val_loss 0.2694, val_acc 91.15%
# Epoch 156. loss: 0.3513, acc: 89.54%, val_loss 0.2682, val_acc 91.20%
# Epoch 157. loss: 0.3595, acc: 88.96%, val_loss 0.2682, val_acc 91.25%
# Epoch 158. loss: 0.3545, acc: 89.85%, val_loss 0.2681, val_acc 91.34%
# Epoch 159. loss: 0.3612, acc: 89.31%, val_loss 0.2683, val_acc 91.29%
# Epoch 160. loss: 0.3571, acc: 89.44%, val_loss 0.2675, val_acc 91.34%
# Epoch 161. loss: 0.3487, acc: 89.37%, val_loss 0.2681, val_acc 91.25%
# Epoch 162. loss: 0.3550, acc: 89.09%, val_loss 0.2678, val_acc 91.20%
# Epoch 163. loss: 0.3569, acc: 89.58%, val_loss 0.2676, val_acc 91.29%
# Epoch 164. loss: 0.3508, acc: 89.44%, val_loss 0.2679, val_acc 91.15%
# Epoch 165. loss: 0.3476, acc: 89.68%, val_loss 0.2681, val_acc 91.15%
# Epoch 166. loss: 0.3467, acc: 89.70%, val_loss 0.2677, val_acc 91.25%
# Epoch 167. loss: 0.3439, acc: 89.65%, val_loss 0.2677, val_acc 91.10%
# Epoch 168. loss: 0.3553, acc: 89.55%, val_loss 0.2680, val_acc 91.10%
# Epoch 169. loss: 0.3539, acc: 89.06%, val_loss 0.2685, val_acc 91.05%
# Epoch 170. loss: 0.3564, acc: 89.35%, val_loss 0.2680, val_acc 91.10%
# Epoch 171. loss: 0.3529, acc: 89.60%, val_loss 0.2678, val_acc 91.20%
# Epoch 172. loss: 0.3575, acc: 89.18%, val_loss 0.2672, val_acc 91.25%
# Epoch 173. loss: 0.3447, acc: 89.51%, val_loss 0.2669, val_acc 91.29%
# Epoch 174. loss: 0.3518, acc: 89.38%, val_loss 0.2668, val_acc 91.25%
# Epoch 175. loss: 0.3555, acc: 89.64%, val_loss 0.2669, val_acc 91.34%
# Epoch 176. loss: 0.3407, acc: 90.15%, val_loss 0.2671, val_acc 91.34%
# Epoch 177. loss: 0.3517, acc: 89.30%, val_loss 0.2671, val_acc 91.05%
# Epoch 178. loss: 0.3567, acc: 88.90%, val_loss 0.2671, val_acc 91.15%
# Epoch 179. loss: 0.3510, acc: 89.45%, val_loss 0.2673, val_acc 91.25%
# Epoch 180. loss: 0.3351, acc: 89.98%, val_loss 0.2678, val_acc 91.44%
# Epoch 181. loss: 0.3343, acc: 89.84%, val_loss 0.2679, val_acc 91.25%
# Epoch 182. loss: 0.3505, acc: 89.78%, val_loss 0.2682, val_acc 91.15%
# Epoch 183. loss: 0.3418, acc: 89.89%, val_loss 0.2685, val_acc 91.10%
# Epoch 184. loss: 0.3621, acc: 89.28%, val_loss 0.2683, val_acc 91.15%
# Epoch 185. loss: 0.3513, acc: 89.79%, val_loss 0.2679, val_acc 91.20%
# Epoch 186. loss: 0.3420, acc: 89.74%, val_loss 0.2677, val_acc 91.20%
# Epoch 187. loss: 0.3392, acc: 89.86%, val_loss 0.2673, val_acc 91.25%
# Epoch 188. loss: 0.3501, acc: 89.50%, val_loss 0.2672, val_acc 91.25%
# Epoch 189. loss: 0.3415, acc: 90.30%, val_loss 0.2672, val_acc 91.20%
# Epoch 190. loss: 0.3504, acc: 89.25%, val_loss 0.2673, val_acc 91.25%
# Epoch 191. loss: 0.3415, acc: 90.10%, val_loss 0.2674, val_acc 91.15%
# Epoch 192. loss: 0.3396, acc: 89.75%, val_loss 0.2676, val_acc 91.25%
# Epoch 193. loss: 0.3279, acc: 90.10%, val_loss 0.2677, val_acc 91.15%
# Epoch 194. loss: 0.3411, acc: 89.76%, val_loss 0.2674, val_acc 91.20%
# Epoch 195. loss: 0.3445, acc: 89.58%, val_loss 0.2668, val_acc 91.34%
# Epoch 196. loss: 0.3333, acc: 89.99%, val_loss 0.2671, val_acc 91.20%
# Epoch 197. loss: 0.3485, acc: 89.59%, val_loss 0.2672, val_acc 91.25%
# Epoch 198. loss: 0.3378, acc: 90.05%, val_loss 0.2670, val_acc 91.29%
# Epoch 199. loss: 0.3441, acc: 89.72%, val_loss 0.2667, val_acc 91.29%
# Epoch 200. loss: 0.3356, acc: 89.97%, val_loss 0.2671, val_acc 91.25%
# Epoch 201. loss: 0.3301, acc: 90.32%, val_loss 0.2670, val_acc 91.29%
# Epoch 202. loss: 0.3400, acc: 89.73%, val_loss 0.2668, val_acc 91.20%
# Epoch 203. loss: 0.3380, acc: 89.89%, val_loss 0.2667, val_acc 91.39%
# Epoch 204. loss: 0.3431, acc: 90.15%, val_loss 0.2668, val_acc 91.24%
# Epoch 205. loss: 0.3311, acc: 90.20%, val_loss 0.2669, val_acc 91.34%
# Epoch 206. loss: 0.3431, acc: 89.67%, val_loss 0.2672, val_acc 91.34%
# Epoch 207. loss: 0.3412, acc: 89.69%, val_loss 0.2673, val_acc 91.24%
# Epoch 208. loss: 0.3357, acc: 89.80%, val_loss 0.2673, val_acc 91.24%
# Epoch 209. loss: 0.3348, acc: 89.96%, val_loss 0.2674, val_acc 91.29%
# Epoch 210. loss: 0.3334, acc: 90.18%, val_loss 0.2671, val_acc 91.34%
# Epoch 211. loss: 0.3384, acc: 90.27%, val_loss 0.2671, val_acc 91.34%
# Epoch 212. loss: 0.3446, acc: 89.72%, val_loss 0.2671, val_acc 91.29%
# Epoch 213. loss: 0.3452, acc: 89.68%, val_loss 0.2668, val_acc 91.29%
# Epoch 214. loss: 0.3327, acc: 89.85%, val_loss 0.2668, val_acc 91.25%
# Epoch 215. loss: 0.3372, acc: 90.06%, val_loss 0.2667, val_acc 91.20%
# Epoch 216. loss: 0.3431, acc: 89.71%, val_loss 0.2669, val_acc 91.15%
# Epoch 217. loss: 0.3446, acc: 89.79%, val_loss 0.2670, val_acc 91.20%
# Epoch 218. loss: 0.3293, acc: 90.04%, val_loss 0.2670, val_acc 91.15%
# Epoch 219. loss: 0.3459, acc: 89.64%, val_loss 0.2671, val_acc 91.20%
# Epoch 220. loss: 0.3329, acc: 90.20%, val_loss 0.2671, val_acc 91.20%
# Epoch 221. loss: 0.3382, acc: 89.70%, val_loss 0.2671, val_acc 91.15%
# Epoch 222. loss: 0.3347, acc: 89.96%, val_loss 0.2671, val_acc 91.15%
# Epoch 223. loss: 0.3250, acc: 90.12%, val_loss 0.2669, val_acc 91.15%
# Epoch 224. loss: 0.3427, acc: 89.94%, val_loss 0.2673, val_acc 91.20%
# Epoch 225. loss: 0.3363, acc: 89.92%, val_loss 0.2673, val_acc 91.25%
# Epoch 226. loss: 0.3410, acc: 90.01%, val_loss 0.2672, val_acc 91.29%
# Epoch 227. loss: 0.3271, acc: 90.16%, val_loss 0.2670, val_acc 91.25%
# Epoch 228. loss: 0.3405, acc: 89.21%, val_loss 0.2671, val_acc 91.20%
# Epoch 229. loss: 0.3313, acc: 90.21%, val_loss 0.2671, val_acc 91.29%
# Epoch 230. loss: 0.3251, acc: 90.28%, val_loss 0.2672, val_acc 91.29%
# Epoch 231. loss: 0.3228, acc: 90.43%, val_loss 0.2673, val_acc 91.34%
# Epoch 232. loss: 0.3239, acc: 90.24%, val_loss 0.2672, val_acc 91.25%
# Epoch 233. loss: 0.3340, acc: 90.00%, val_loss 0.2672, val_acc 91.29%
# Epoch 234. loss: 0.3340, acc: 90.30%, val_loss 0.2672, val_acc 91.25%
# Epoch 235. loss: 0.3344, acc: 89.97%, val_loss 0.2675, val_acc 91.25%
# Epoch 236. loss: 0.3358, acc: 90.06%, val_loss 0.2674, val_acc 91.20%
# Epoch 237. loss: 0.3351, acc: 89.96%, val_loss 0.2675, val_acc 91.20%
# Epoch 238. loss: 0.3291, acc: 90.30%, val_loss 0.2675, val_acc 91.25%
# Epoch 239. loss: 0.3390, acc: 89.89%, val_loss 0.2676, val_acc 91.25%
# Epoch 240. loss: 0.3388, acc: 89.36%, val_loss 0.2673, val_acc 91.25%
# Epoch 241. loss: 0.3347, acc: 89.80%, val_loss 0.2673, val_acc 91.29%
# Epoch 242. loss: 0.3271, acc: 90.33%, val_loss 0.2672, val_acc 91.25%
# Epoch 243. loss: 0.3416, acc: 89.34%, val_loss 0.2672, val_acc 91.29%
# Epoch 244. loss: 0.3344, acc: 89.48%, val_loss 0.2672, val_acc 91.29%
# Epoch 245. loss: 0.3215, acc: 90.74%, val_loss 0.2673, val_acc 91.29%
# Epoch 246. loss: 0.3305, acc: 90.33%, val_loss 0.2671, val_acc 91.29%
# Epoch 247. loss: 0.3318, acc: 89.75%, val_loss 0.2672, val_acc 91.29%
# Epoch 248. loss: 0.3487, acc: 89.44%, val_loss 0.2671, val_acc 91.29%
# Epoch 249. loss: 0.3329, acc: 90.07%, val_loss 0.2671, val_acc 91.29%
# Epoch 250. loss: 0.3337, acc: 89.97%, val_loss 0.2673, val_acc 91.34%
# Epoch 251. loss: 0.3320, acc: 90.27%, val_loss 0.2673, val_acc 91.34%
# Epoch 252. loss: 0.3262, acc: 90.19%, val_loss 0.2671, val_acc 91.29%
# Epoch 253. loss: 0.3300, acc: 90.39%, val_loss 0.2671, val_acc 91.29%
# Epoch 254. loss: 0.3316, acc: 90.20%, val_loss 0.2671, val_acc 91.34%
# Epoch 255. loss: 0.3157, acc: 90.47%, val_loss 0.2672, val_acc 91.25%
# Epoch 256. loss: 0.3253, acc: 90.10%, val_loss 0.2673, val_acc 91.25%
# Epoch 257. loss: 0.3425, acc: 89.87%, val_loss 0.2671, val_acc 91.29%
# Epoch 258. loss: 0.3297, acc: 90.64%, val_loss 0.2670, val_acc 91.29%
# Epoch 259. loss: 0.3236, acc: 90.04%, val_loss 0.2670, val_acc 91.29%
# Epoch 260. loss: 0.3300, acc: 90.04%, val_loss 0.2670, val_acc 91.25%
# Epoch 261. loss: 0.3328, acc: 89.71%, val_loss 0.2669, val_acc 91.29%
# Epoch 262. loss: 0.3175, acc: 90.72%, val_loss 0.2670, val_acc 91.34%
# Epoch 263. loss: 0.3193, acc: 90.31%, val_loss 0.2669, val_acc 91.25%
# Epoch 264. loss: 0.3302, acc: 90.49%, val_loss 0.2669, val_acc 91.29%
# Epoch 265. loss: 0.3263, acc: 90.45%, val_loss 0.2671, val_acc 91.25%
# Epoch 266. loss: 0.3247, acc: 90.20%, val_loss 0.2671, val_acc 91.29%
# Epoch 267. loss: 0.3366, acc: 89.78%, val_loss 0.2671, val_acc 91.29%
# Epoch 268. loss: 0.3277, acc: 90.15%, val_loss 0.2671, val_acc 91.29%
# Epoch 269. loss: 0.3187, acc: 90.52%, val_loss 0.2671, val_acc 91.34%
# Epoch 270. loss: 0.3259, acc: 90.27%, val_loss 0.2671, val_acc 91.29%
# Epoch 271. loss: 0.3286, acc: 90.00%, val_loss 0.2671, val_acc 91.39%
# Epoch 272. loss: 0.3239, acc: 90.40%, val_loss 0.2672, val_acc 91.29%
# Epoch 273. loss: 0.3317, acc: 89.67%, val_loss 0.2670, val_acc 91.25%
# Epoch 274. loss: 0.3230, acc: 90.52%, val_loss 0.2670, val_acc 91.25%
# Epoch 275. loss: 0.3175, acc: 90.90%, val_loss 0.2668, val_acc 91.25%
# Epoch 276. loss: 0.3308, acc: 89.97%, val_loss 0.2668, val_acc 91.25%
# Epoch 277. loss: 0.3313, acc: 90.47%, val_loss 0.2669, val_acc 91.25%
# Epoch 278. loss: 0.3376, acc: 90.21%, val_loss 0.2669, val_acc 91.25%
# Epoch 279. loss: 0.3325, acc: 89.96%, val_loss 0.2668, val_acc 91.29%
# Epoch 280. loss: 0.3265, acc: 90.24%, val_loss 0.2667, val_acc 91.34%
# Epoch 281. loss: 0.3254, acc: 90.20%, val_loss 0.2668, val_acc 91.29%
# Epoch 282. loss: 0.3287, acc: 89.95%, val_loss 0.2668, val_acc 91.29%
# Epoch 283. loss: 0.3288, acc: 90.12%, val_loss 0.2668, val_acc 91.34%
# Epoch 284. loss: 0.3262, acc: 90.13%, val_loss 0.2669, val_acc 91.34%
# Epoch 285. loss: 0.3333, acc: 89.86%, val_loss 0.2669, val_acc 91.34%
# Epoch 286. loss: 0.3412, acc: 89.67%, val_loss 0.2668, val_acc 91.29%
# Epoch 287. loss: 0.3358, acc: 89.41%, val_loss 0.2668, val_acc 91.25%
# Epoch 288. loss: 0.3269, acc: 90.07%, val_loss 0.2668, val_acc 91.25%
# Epoch 289. loss: 0.3457, acc: 89.51%, val_loss 0.2668, val_acc 91.25%
# Epoch 290. loss: 0.3381, acc: 89.67%, val_loss 0.2669, val_acc 91.25%
# Epoch 291. loss: 0.3420, acc: 89.31%, val_loss 0.2668, val_acc 91.25%
# Epoch 292. loss: 0.3307, acc: 90.00%, val_loss 0.2668, val_acc 91.29%
# Epoch 293. loss: 0.3316, acc: 90.16%, val_loss 0.2668, val_acc 91.25%
# Epoch 294. loss: 0.3277, acc: 90.21%, val_loss 0.2667, val_acc 91.25%
# Epoch 295. loss: 0.3162, acc: 90.16%, val_loss 0.2667, val_acc 91.29%
# Epoch 296. loss: 0.3241, acc: 90.37%, val_loss 0.2667, val_acc 91.20%
# Epoch 297. loss: 0.3304, acc: 90.40%, val_loss 0.2667, val_acc 91.20%
# Epoch 298. loss: 0.3315, acc: 90.05%, val_loss 0.2666, val_acc 91.20%
# Epoch 299. loss: 0.3257, acc: 90.19%, val_loss 0.2667, val_acc 91.20%
# Epoch 300. loss: 0.3334, acc: 89.76%, val_loss 0.2668, val_acc 91.20%
# Epoch 301. loss: 0.3172, acc: 90.61%, val_loss 0.2668, val_acc 91.20%
# Epoch 302. loss: 0.3379, acc: 89.98%, val_loss 0.2668, val_acc 91.20%
# Epoch 303. loss: 0.3299, acc: 90.11%, val_loss 0.2668, val_acc 91.20%
# Epoch 304. loss: 0.3260, acc: 90.24%, val_loss 0.2668, val_acc 91.20%
# Epoch 305. loss: 0.3281, acc: 90.49%, val_loss 0.2668, val_acc 91.20%
# Epoch 306. loss: 0.3334, acc: 89.99%, val_loss 0.2668, val_acc 91.20%
# Epoch 307. loss: 0.3263, acc: 90.10%, val_loss 0.2668, val_acc 91.20%
# Epoch 308. loss: 0.3238, acc: 90.40%, val_loss 0.2668, val_acc 91.20%
# Epoch 309. loss: 0.3339, acc: 89.86%, val_loss 0.2668, val_acc 91.25%
# Epoch 310. loss: 0.3142, acc: 91.01%, val_loss 0.2668, val_acc 91.25%
# Epoch 311. loss: 0.3245, acc: 90.46%, val_loss 0.2668, val_acc 91.29%
# Epoch 312. loss: 0.3226, acc: 90.47%, val_loss 0.2668, val_acc 91.25%
# Epoch 313. loss: 0.3300, acc: 90.12%, val_loss 0.2668, val_acc 91.25%
# Epoch 314. loss: 0.3263, acc: 90.39%, val_loss 0.2668, val_acc 91.20%
# Epoch 315. loss: 0.3345, acc: 90.16%, val_loss 0.2668, val_acc 91.29%
# Epoch 316. loss: 0.3318, acc: 89.71%, val_loss 0.2668, val_acc 91.29%
# Epoch 317. loss: 0.3272, acc: 90.41%, val_loss 0.2668, val_acc 91.29%
# Epoch 318. loss: 0.3403, acc: 89.70%, val_loss 0.2668, val_acc 91.29%
# Epoch 319. loss: 0.3244, acc: 90.58%, val_loss 0.2668, val_acc 91.29%
# Epoch 320. loss: 0.3174, acc: 90.38%, val_loss 0.2667, val_acc 91.25%
# Epoch 321. loss: 0.3412, acc: 89.38%, val_loss 0.2667, val_acc 91.25%
# Epoch 322. loss: 0.3302, acc: 90.52%, val_loss 0.2667, val_acc 91.20%
# Epoch 323. loss: 0.3240, acc: 90.02%, val_loss 0.2667, val_acc 91.20%
# Epoch 324. loss: 0.3196, acc: 90.33%, val_loss 0.2666, val_acc 91.20%
# Epoch 325. loss: 0.3184, acc: 90.72%, val_loss 0.2666, val_acc 91.20%
# Epoch 326. loss: 0.3184, acc: 90.38%, val_loss 0.2666, val_acc 91.25%
# Epoch 327. loss: 0.3306, acc: 90.11%, val_loss 0.2666, val_acc 91.25%
# Epoch 328. loss: 0.3304, acc: 89.84%, val_loss 0.2666, val_acc 91.20%
# Epoch 329. loss: 0.3194, acc: 90.23%, val_loss 0.2666, val_acc 91.20%
# Epoch 330. loss: 0.3190, acc: 90.34%, val_loss 0.2666, val_acc 91.25%
# Epoch 331. loss: 0.3290, acc: 89.98%, val_loss 0.2666, val_acc 91.25%
# Epoch 332. loss: 0.3288, acc: 90.49%, val_loss 0.2666, val_acc 91.25%
# Epoch 333. loss: 0.3259, acc: 90.15%, val_loss 0.2666, val_acc 91.25%
# Epoch 334. loss: 0.3318, acc: 90.05%, val_loss 0.2666, val_acc 91.25%
# Epoch 335. loss: 0.3407, acc: 89.91%, val_loss 0.2666, val_acc 91.20%
# Epoch 336. loss: 0.3237, acc: 90.20%, val_loss 0.2667, val_acc 91.20%
# Epoch 337. loss: 0.3312, acc: 89.89%, val_loss 0.2667, val_acc 91.25%
# Epoch 338. loss: 0.3313, acc: 90.14%, val_loss 0.2667, val_acc 91.25%
# Epoch 339. loss: 0.3188, acc: 90.44%, val_loss 0.2666, val_acc 91.25%
# Epoch 340. loss: 0.3423, acc: 89.61%, val_loss 0.2667, val_acc 91.25%
# Epoch 341. loss: 0.3288, acc: 90.09%, val_loss 0.2667, val_acc 91.20%
# Epoch 342. loss: 0.3209, acc: 90.06%, val_loss 0.2666, val_acc 91.25%
# Epoch 343. loss: 0.3183, acc: 90.84%, val_loss 0.2667, val_acc 91.25%
# Epoch 344. loss: 0.3253, acc: 90.39%, val_loss 0.2666, val_acc 91.25%
# Epoch 345. loss: 0.3303, acc: 90.29%, val_loss 0.2667, val_acc 91.25%
# Epoch 346. loss: 0.3250, acc: 90.06%, val_loss 0.2667, val_acc 91.29%
# Epoch 347. loss: 0.3228, acc: 90.05%, val_loss 0.2666, val_acc 91.29%
# Epoch 348. loss: 0.3083, acc: 90.59%, val_loss 0.2666, val_acc 91.29%
# Epoch 349. loss: 0.3234, acc: 90.33%, val_loss 0.2666, val_acc 91.29%
# Epoch 350. loss: 0.3295, acc: 90.34%, val_loss 0.2666, val_acc 91.29%
# Epoch 351. loss: 0.3325, acc: 90.03%, val_loss 0.2666, val_acc 91.29%
# Epoch 352. loss: 0.3186, acc: 90.11%, val_loss 0.2666, val_acc 91.29%
# Epoch 353. loss: 0.3233, acc: 90.37%, val_loss 0.2666, val_acc 91.29%
# Epoch 354. loss: 0.3279, acc: 90.08%, val_loss 0.2666, val_acc 91.25%
# Epoch 355. loss: 0.3225, acc: 90.27%, val_loss 0.2666, val_acc 91.29%
# Epoch 356. loss: 0.3274, acc: 90.00%, val_loss 0.2666, val_acc 91.29%
# Epoch 357. loss: 0.3218, acc: 90.14%, val_loss 0.2666, val_acc 91.25%
# Epoch 358. loss: 0.3282, acc: 90.46%, val_loss 0.2666, val_acc 91.29%
# Epoch 359. loss: 0.3149, acc: 90.42%, val_loss 0.2667, val_acc 91.25%
# Epoch 360. loss: 0.3323, acc: 89.94%, val_loss 0.2666, val_acc 91.25%
# Epoch 361. loss: 0.3263, acc: 90.64%, val_loss 0.2666, val_acc 91.25%
# Epoch 362. loss: 0.3117, acc: 90.66%, val_loss 0.2666, val_acc 91.25%
# Epoch 363. loss: 0.3322, acc: 89.98%, val_loss 0.2666, val_acc 91.25%
# Epoch 364. loss: 0.3241, acc: 90.37%, val_loss 0.2666, val_acc 91.25%
# Epoch 365. loss: 0.3202, acc: 90.13%, val_loss 0.2666, val_acc 91.29%
# Epoch 366. loss: 0.3157, acc: 90.87%, val_loss 0.2666, val_acc 91.29%
# Epoch 367. loss: 0.3230, acc: 90.21%, val_loss 0.2666, val_acc 91.25%
# Epoch 368. loss: 0.3346, acc: 89.85%, val_loss 0.2666, val_acc 91.25%
# Epoch 369. loss: 0.3365, acc: 89.86%, val_loss 0.2666, val_acc 91.25%
# Epoch 370. loss: 0.3199, acc: 90.87%, val_loss 0.2666, val_acc 91.29%
# Epoch 371. loss: 0.3269, acc: 90.55%, val_loss 0.2666, val_acc 91.25%
# Epoch 372. loss: 0.3335, acc: 89.97%, val_loss 0.2666, val_acc 91.25%
# Epoch 373. loss: 0.3234, acc: 90.28%, val_loss 0.2666, val_acc 91.25%
# Epoch 374. loss: 0.3204, acc: 90.60%, val_loss 0.2666, val_acc 91.25%
# Epoch 375. loss: 0.3330, acc: 90.13%, val_loss 0.2666, val_acc 91.25%
# Epoch 376. loss: 0.3210, acc: 90.14%, val_loss 0.2666, val_acc 91.29%
# Epoch 377. loss: 0.3252, acc: 89.89%, val_loss 0.2666, val_acc 91.25%
# Epoch 378. loss: 0.3291, acc: 89.95%, val_loss 0.2666, val_acc 91.25%
# Epoch 379. loss: 0.3195, acc: 90.10%, val_loss 0.2666, val_acc 91.25%
# Epoch 380. loss: 0.3243, acc: 90.11%, val_loss 0.2666, val_acc 91.29%
# Epoch 381. loss: 0.3234, acc: 90.35%, val_loss 0.2666, val_acc 91.29%
# Epoch 382. loss: 0.3311, acc: 90.10%, val_loss 0.2666, val_acc 91.29%
# Epoch 383. loss: 0.3222, acc: 90.39%, val_loss 0.2666, val_acc 91.29%
# Epoch 384. loss: 0.3178, acc: 90.42%, val_loss 0.2666, val_acc 91.29%
# Epoch 385. loss: 0.3328, acc: 89.88%, val_loss 0.2666, val_acc 91.29%
# Epoch 386. loss: 0.3351, acc: 89.83%, val_loss 0.2666, val_acc 91.29%
# Epoch 387. loss: 0.3278, acc: 90.28%, val_loss 0.2666, val_acc 91.29%
# Epoch 388. loss: 0.3220, acc: 90.46%, val_loss 0.2666, val_acc 91.25%
# Epoch 389. loss: 0.3288, acc: 90.34%, val_loss 0.2666, val_acc 91.25%
# Epoch 390. loss: 0.3295, acc: 90.15%, val_loss 0.2666, val_acc 91.25%
# Epoch 391. loss: 0.3244, acc: 90.22%, val_loss 0.2666, val_acc 91.29%
# Epoch 392. loss: 0.3167, acc: 90.54%, val_loss 0.2666, val_acc 91.29%
# Epoch 393. loss: 0.3209, acc: 90.53%, val_loss 0.2666, val_acc 91.29%
# Epoch 394. loss: 0.3297, acc: 90.22%, val_loss 0.2666, val_acc 91.29%
# Epoch 395. loss: 0.3283, acc: 89.91%, val_loss 0.2666, val_acc 91.29%
# Epoch 396. loss: 0.3272, acc: 90.21%, val_loss 0.2666, val_acc 91.29%
# Epoch 397. loss: 0.3292, acc: 89.49%, val_loss 0.2666, val_acc 91.29%
# Epoch 398. loss: 0.3297, acc: 90.23%, val_loss 0.2666, val_acc 91.29%
# Epoch 399. loss: 0.3347, acc: 90.03%, val_loss 0.2666, val_acc 91.29%
# Epoch 400. loss: 0.3278, acc: 90.20%, val_loss 0.2666, val_acc 91.29%
# Epoch 401. loss: 0.3214, acc: 90.00%, val_loss 0.2666, val_acc 91.29%
# Epoch 402. loss: 0.3203, acc: 90.24%, val_loss 0.2666, val_acc 91.29%
# Epoch 403. loss: 0.3268, acc: 90.10%, val_loss 0.2666, val_acc 91.29%
# Epoch 404. loss: 0.3231, acc: 90.02%, val_loss 0.2666, val_acc 91.29%
# Epoch 405. loss: 0.3345, acc: 89.97%, val_loss 0.2666, val_acc 91.29%
# Epoch 406. loss: 0.3124, acc: 90.36%, val_loss 0.2666, val_acc 91.29%
# Epoch 407. loss: 0.3242, acc: 90.22%, val_loss 0.2666, val_acc 91.29%
# Epoch 408. loss: 0.3356, acc: 89.94%, val_loss 0.2666, val_acc 91.29%
# Epoch 409. loss: 0.3277, acc: 90.32%, val_loss 0.2666, val_acc 91.29%
# Epoch 410. loss: 0.3233, acc: 90.44%, val_loss 0.2666, val_acc 91.29%
# Epoch 411. loss: 0.3278, acc: 90.38%, val_loss 0.2666, val_acc 91.29%
# Epoch 412. loss: 0.3235, acc: 90.38%, val_loss 0.2666, val_acc 91.29%
# Epoch 413. loss: 0.3335, acc: 90.20%, val_loss 0.2665, val_acc 91.29%
# Epoch 414. loss: 0.3257, acc: 90.54%, val_loss 0.2665, val_acc 91.29%
# Epoch 415. loss: 0.3194, acc: 90.40%, val_loss 0.2665, val_acc 91.29%
# Epoch 416. loss: 0.3424, acc: 89.66%, val_loss 0.2665, val_acc 91.29%
# Epoch 417. loss: 0.3223, acc: 90.67%, val_loss 0.2666, val_acc 91.29%
# Epoch 418. loss: 0.3251, acc: 90.11%, val_loss 0.2665, val_acc 91.29%
# Epoch 419. loss: 0.3193, acc: 90.24%, val_loss 0.2666, val_acc 91.29%
# Epoch 420. loss: 0.3146, acc: 90.48%, val_loss 0.2666, val_acc 91.29%
# Epoch 421. loss: 0.3239, acc: 90.04%, val_loss 0.2666, val_acc 91.29%
# Epoch 422. loss: 0.3249, acc: 90.19%, val_loss 0.2666, val_acc 91.29%
# Epoch 423. loss: 0.3295, acc: 90.45%, val_loss 0.2666, val_acc 91.29%
# Epoch 424. loss: 0.3229, acc: 90.03%, val_loss 0.2666, val_acc 91.29%
# Epoch 425. loss: 0.3173, acc: 89.94%, val_loss 0.2666, val_acc 91.29%
# Epoch 426. loss: 0.3277, acc: 90.48%, val_loss 0.2666, val_acc 91.29%
# Epoch 427. loss: 0.3308, acc: 89.82%, val_loss 0.2666, val_acc 91.29%
# Epoch 428. loss: 0.3265, acc: 90.34%, val_loss 0.2666, val_acc 91.29%
# Epoch 429. loss: 0.3237, acc: 90.09%, val_loss 0.2666, val_acc 91.29%
# Epoch 430. loss: 0.3192, acc: 90.50%, val_loss 0.2666, val_acc 91.29%
# Epoch 431. loss: 0.3210, acc: 90.25%, val_loss 0.2666, val_acc 91.29%
# Epoch 432. loss: 0.3240, acc: 90.20%, val_loss 0.2666, val_acc 91.29%
# Epoch 433. loss: 0.3203, acc: 90.37%, val_loss 0.2666, val_acc 91.29%
# Epoch 434. loss: 0.3209, acc: 90.53%, val_loss 0.2666, val_acc 91.29%
# Epoch 435. loss: 0.3219, acc: 90.08%, val_loss 0.2666, val_acc 91.29%
# Epoch 436. loss: 0.3277, acc: 90.14%, val_loss 0.2666, val_acc 91.29%
# Epoch 437. loss: 0.3130, acc: 90.95%, val_loss 0.2666, val_acc 91.29%
# Epoch 438. loss: 0.3173, acc: 90.38%, val_loss 0.2666, val_acc 91.29%
# Epoch 439. loss: 0.3172, acc: 90.38%, val_loss 0.2666, val_acc 91.29%
# Epoch 440. loss: 0.3327, acc: 89.83%, val_loss 0.2666, val_acc 91.29%
# Epoch 441. loss: 0.3242, acc: 90.32%, val_loss 0.2666, val_acc 91.25%
# Epoch 442. loss: 0.3183, acc: 90.60%, val_loss 0.2666, val_acc 91.25%
# Epoch 443. loss: 0.3245, acc: 90.16%, val_loss 0.2666, val_acc 91.25%
# Epoch 444. loss: 0.3211, acc: 90.39%, val_loss 0.2666, val_acc 91.25%
# Epoch 445. loss: 0.3321, acc: 90.15%, val_loss 0.2666, val_acc 91.25%
# Epoch 446. loss: 0.3151, acc: 90.41%, val_loss 0.2666, val_acc 91.25%
# Epoch 447. loss: 0.3296, acc: 90.19%, val_loss 0.2666, val_acc 91.25%
# Epoch 448. loss: 0.3241, acc: 89.96%, val_loss 0.2666, val_acc 91.25%
# Epoch 449. loss: 0.3188, acc: 90.22%, val_loss 0.2666, val_acc 91.25%
# Epoch 450. loss: 0.3237, acc: 90.47%, val_loss 0.2666, val_acc 91.25%
# Epoch 451. loss: 0.3231, acc: 90.52%, val_loss 0.2666, val_acc 91.25%
# Epoch 452. loss: 0.3268, acc: 90.14%, val_loss 0.2666, val_acc 91.25%
# Epoch 453. loss: 0.3325, acc: 89.96%, val_loss 0.2666, val_acc 91.25%
# Epoch 454. loss: 0.3269, acc: 90.06%, val_loss 0.2666, val_acc 91.25%
# Epoch 455. loss: 0.3250, acc: 90.34%, val_loss 0.2666, val_acc 91.25%
# Epoch 456. loss: 0.3165, acc: 90.66%, val_loss 0.2666, val_acc 91.25%
# Epoch 457. loss: 0.3183, acc: 90.43%, val_loss 0.2666, val_acc 91.25%
# Epoch 458. loss: 0.3113, acc: 90.69%, val_loss 0.2666, val_acc 91.25%
# Epoch 459. loss: 0.3182, acc: 90.17%, val_loss 0.2666, val_acc 91.25%
# Epoch 460. loss: 0.3233, acc: 90.16%, val_loss 0.2666, val_acc 91.25%
# Epoch 461. loss: 0.3222, acc: 90.11%, val_loss 0.2666, val_acc 91.25%
# Epoch 462. loss: 0.3230, acc: 90.36%, val_loss 0.2666, val_acc 91.25%
# Epoch 463. loss: 0.3313, acc: 90.38%, val_loss 0.2666, val_acc 91.25%
# Epoch 464. loss: 0.3235, acc: 90.29%, val_loss 0.2666, val_acc 91.25%
# Epoch 465. loss: 0.3228, acc: 90.67%, val_loss 0.2666, val_acc 91.25%
# Epoch 466. loss: 0.3303, acc: 90.05%, val_loss 0.2666, val_acc 91.25%
# Epoch 467. loss: 0.3219, acc: 90.44%, val_loss 0.2666, val_acc 91.25%
# Epoch 468. loss: 0.3342, acc: 89.83%, val_loss 0.2666, val_acc 91.25%
# Epoch 469. loss: 0.3263, acc: 90.34%, val_loss 0.2666, val_acc 91.25%
# Epoch 470. loss: 0.3135, acc: 90.44%, val_loss 0.2666, val_acc 91.25%
# Epoch 471. loss: 0.3162, acc: 90.56%, val_loss 0.2666, val_acc 91.25%
# Epoch 472. loss: 0.3202, acc: 90.58%, val_loss 0.2666, val_acc 91.25%
# Epoch 473. loss: 0.3300, acc: 90.25%, val_loss 0.2666, val_acc 91.25%
# Epoch 474. loss: 0.3250, acc: 90.58%, val_loss 0.2666, val_acc 91.25%
# Epoch 475. loss: 0.3356, acc: 90.15%, val_loss 0.2666, val_acc 91.25%
# Epoch 476. loss: 0.3254, acc: 90.22%, val_loss 0.2666, val_acc 91.25%
# Epoch 477. loss: 0.3178, acc: 90.85%, val_loss 0.2666, val_acc 91.25%
# Epoch 478. loss: 0.3250, acc: 90.62%, val_loss 0.2666, val_acc 91.25%
# Epoch 479. loss: 0.3264, acc: 89.96%, val_loss 0.2666, val_acc 91.25%
# Epoch 480. loss: 0.3153, acc: 90.48%, val_loss 0.2666, val_acc 91.25%
# Epoch 481. loss: 0.3219, acc: 90.27%, val_loss 0.2666, val_acc 91.25%
# Epoch 482. loss: 0.3217, acc: 90.28%, val_loss 0.2666, val_acc 91.25%
# Epoch 483. loss: 0.3312, acc: 90.16%, val_loss 0.2666, val_acc 91.25%
# Epoch 484. loss: 0.3284, acc: 90.25%, val_loss 0.2666, val_acc 91.25%
# Epoch 485. loss: 0.3402, acc: 89.81%, val_loss 0.2666, val_acc 91.25%
# Epoch 486. loss: 0.3202, acc: 90.42%, val_loss 0.2666, val_acc 91.25%
# Epoch 487. loss: 0.3129, acc: 90.85%, val_loss 0.2666, val_acc 91.25%
# Epoch 488. loss: 0.3282, acc: 90.47%, val_loss 0.2666, val_acc 91.25%
# Epoch 489. loss: 0.3346, acc: 89.93%, val_loss 0.2666, val_acc 91.25%
# Epoch 490. loss: 0.3250, acc: 90.44%, val_loss 0.2666, val_acc 91.25%
# Epoch 491. loss: 0.3105, acc: 90.78%, val_loss 0.2666, val_acc 91.25%
# Epoch 492. loss: 0.3329, acc: 89.85%, val_loss 0.2666, val_acc 91.25%
# Epoch 493. loss: 0.3260, acc: 90.42%, val_loss 0.2666, val_acc 91.25%
# Epoch 494. loss: 0.3280, acc: 90.19%, val_loss 0.2666, val_acc 91.25%
# Epoch 495. loss: 0.3336, acc: 90.19%, val_loss 0.2666, val_acc 91.25%
# Epoch 496. loss: 0.3240, acc: 90.32%, val_loss 0.2666, val_acc 91.25%
# Epoch 497. loss: 0.3247, acc: 90.15%, val_loss 0.2666, val_acc 91.25%
# Epoch 498. loss: 0.3197, acc: 90.47%, val_loss 0.2666, val_acc 91.25%
# Epoch 499. loss: 0.3207, acc: 90.45%, val_loss 0.2666, val_acc 91.25%
# Epoch 500. loss: 0.3291, acc: 90.06%, val_loss 0.2666, val_acc 91.25%

# %%
features_test = [nd.load(os.path.join(features_dir,'features_test_%s.nd' % model_name))[0] for model_name in model_names]
features_test = nd.concat(*features_test, dim=1)

# %%
output = nd.softmax(net(features_test.as_in_context(ctx))).asnumpy()
df_pred = pd.read_csv(os.path.join(data_dir,'sample_submission.csv'))
for i, c in enumerate(df_pred.columns[1:]):
    df_pred[c] = output[:,i]

df_pred.to_csv('pred_0.260.csv', index=None)

# %%
zip(np.argmax(pd.read_csv('pred_0.28.csv').values[:,1:], axis=-1), np.argmax(df_pred.values[:,1:], axis=-1))[:10]
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-15-1407a7a41d50> in <module>()
# ----> 1 zip(np.argmax(pd.read_csv('pred_0.28.csv').values[:,1:], axis=-1), np.argmax(df_pred.values[:,1:], axis=-1))[:10]
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/io/parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, escapechar, comment, encoding, dialect, tupleize_cols, error_bad_lines, warn_bad_lines, skipfooter, skip_footer, doublequote, delim_whitespace, as_recarray, compact_ints, use_unsigned, low_memory, buffer_lines, memory_map, float_precision)
#     703                     skip_blank_lines=skip_blank_lines)
#     704
# --> 705         return _read(filepath_or_buffer, kwds)
#     706
#     707     parser_f.__name__ = name
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/io/parsers.py in _read(filepath_or_buffer, kwds)
#     443
#     444     # Create the parser.
# --> 445     parser = TextFileReader(filepath_or_buffer, **kwds)
#     446
#     447     if chunksize or iterator:
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, f, engine, **kwds)
#     812             self.options['has_index_names'] = kwds['has_index_names']
#     813
# --> 814         self._make_engine(self.engine)
#     815
#     816     def close(self):
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/io/parsers.py in _make_engine(self, engine)
#    1043     def _make_engine(self, engine='c'):
#    1044         if engine == 'c':
# -> 1045             self._engine = CParserWrapper(self.f, **self.options)
#    1046         else:
#    1047             if engine == 'python':
#
# ~/miniconda3/envs/gluon/lib/python3.6/site-packages/pandas/io/parsers.py in __init__(self, src, **kwds)
#    1682         kwds['allow_leading_cols'] = self.index_col is not False
#    1683
# -> 1684         self._reader = parsers.TextReader(src, **kwds)
#    1685
#    1686         # XXX
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader.__cinit__()
#
# pandas/_libs/parsers.pyx in pandas._libs.parsers.TextReader._setup_parser_source()
#
# FileNotFoundError: File b'pred_0.28.csv' does not exist
